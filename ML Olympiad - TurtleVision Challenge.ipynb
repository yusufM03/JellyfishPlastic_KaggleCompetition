# %% [markdown]
# <div style="text-align: center; background: #ff8c00; font-family: 'Montserrat', sans-serif; color: white; padding: 15px; font-size: 30px; font-weight: bold; line-height: 1; border-radius: 20px 20px 0 0; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.2);">
#   🚀 ML Olympiad - TurtleVision Challenge: Illuminate the path to ocean and plastic pollution awareness  🚀
# </div

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Life Cycle of the Project</div>

# %% [markdown]
# <div style="font-size: 14px; font-family: Verdana; border: 2px solid #ccc; background-color: #F5F5F5; padding: 10px; border-radius: 10px; margin-bottom: 20px; position: relative;">
#
#   <!-- Add the image inside the div, aligned to the right-center -->
#    <img src="https://media.giphy.com/media/2lQzj96U6fb5qbknOW/giphy.gif" style="position: absolute; left:40%; right: 0; transform: translateY(-50%); width: 200px; height: auto;">
#    <img src="https://media.giphy.com/media/2lQzj96U6fb5qbknOW/giphy.gif" style="position: absolute; left:60%; right: 0; transform: translateY(-50%); width: 200px; height: auto;">
#
#   <span style="color: #FF5733; font-weight: bold;">Steps to be Performed</span>
#   <ol>
#     <li><a href="#1">Problem Statement 🙋</a></li>
#     <li><a href="#2">Data Checks 🔍</a></li>
#     <li><a href="#3">Data Preprocessing ✍️</a></li>
#     <li><a href="#4">Model Training with different architectures🤖</a></li>
#     <li><a href="#5">Model Training with Vit 🤖</a></li>
#     <li><a href="#6">Evaluation 📈</a></li>
#     <li><a href="#6">Author Message ✉️</a></li>
#   </ol>
# </div>

# %% [markdown]
# <a id="1"></a>
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">1. Problem Statement</div>

# %% [markdown]
# <div style="font-size: 14px; font-family: Verdana; border: 2px solid #ccc; background-color: #F5F5F5; padding: 10px; border-radius: 10px; display: inline-block; margin-bottom: 20px;">
#   The primary goal of this notebook is to develop a predictive model that accurately classifies images as either <span style="background-color: #FF5733; color: white; font-weight: bold; padding: 3px 6px; border-radius: 3px;">type of Jellyfish</span> or <span style="background-color: #FF5733; color: white; font-weight: bold; padding: 3px 6px; border-radius: 3px;">plastic</span>. We will use the dataset provided in the Kaggle competition, which consist OF 1380 images with their respective labels.
# </div>
# >

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">2. Data Checks 🔍</div>

# %% [markdown]
# <div style="text-align: center; background:  #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">2.1 Import Necessary Libraries</div>

# %%
import pandas as pd 
import numpy as np
import os 
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import cv2
# Set random seed for TensorFlow
tf.random.set_seed(42)

# %% [markdown]
# <div style="text-align: center; background:  #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">2.2 Load the Data</div>

# %%
train_dir="train"
test_dir="test"

# %%
X=[]
y=[]
for classe in os.listdir(train_dir):
    
    for img in os.listdir(os.path.join(train_dir,classe)):
        image_path=os.path.join(train_dir,classe,img)
        img = tf.io.read_file(image_path)
        img = tf.io.decode_jpeg(img, channels = 3)
        img = tf.image.resize(img, size = (224,224))
        img = tf.cast(img, tf.float32) / 255.0
        
        #original_image = cv2.imread(image_path) 
        #original_image=cv2.resize(original_image ,(244,244))
         # Convert the image from BGR to HSV color space
    
       
        X.append(img)
            
            
        y.append(classe)

# %%
X[0]
# Out:
# <tf.Tensor: shape=(120, 120, 3), dtype=float32, numpy=
# array([[[0.17627233, 0.5352288 , 0.31169933],
#         [0.16836601, 0.53738564, 0.31169933],
#         [0.15805012, 0.5422821 , 0.31954247],
#         ...,
#         [0.22242373, 0.31346402, 0.10954244],
#         [0.23438236, 0.3254902 , 0.12156863],
#         [0.22849788, 0.31967324, 0.11575168]],
#
#        [[0.16418302, 0.5383693 , 0.31849998],
#         [0.15413725, 0.5372549 , 0.3145196 ],
#         [0.13887256, 0.5372549 , 0.30928102],
#         ...,
#         [0.22508176, 0.32877448, 0.12980391],
#         [0.22489218, 0.32883334, 0.12980393],
#         [0.21849358, 0.32268304, 0.12359481]],
#
#        [[0.14941722, 0.53843683, 0.32235837],
#         [0.143317  , 0.54044116, 0.32156864],
#         [0.13238019, 0.5427832 , 0.31993464],
#         ...,
#         [0.22840416, 0.34872   , 0.15359476],
#         [0.22266342, 0.34308824, 0.1479085 ],
#         [0.21463513, 0.33516887, 0.13993467]],
#
#        ...,
#
# ...

# %%
import numpy as np
import cv2
import random

# Function to apply random rotation
def random_rotation(image):
    angle = random.randint(-15, 15)
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

# Function to apply random horizontal flip
def random_horizontal_flip(image):
    if random.random() < 0.5:
        image = cv2.flip(image, 1)
    return image

# Function to apply random vertical flip
def random_vertical_flip(image):
    if random.random() < 0.5:
        image = cv2.flip(image, 0)
    return image


# Load and preprocess your images
augmented_images = []
for i,image in enumerate(X):
    augmented_image = random_horizontal_flip(image)
    a= random_vertical_flip(augmented_image )
    
    
    augmented_images.append(augmented_image)
    augmented_images.Append(a)
    y.append(y[i])
    y.append(y[i])
    

# Convert list of augmented images to numpy array
augmented_images = np.array(augmented_images)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 30
#      28 augmented_images = []
#      29 for i,image in enumerate(X):
# ---> 30     augmented_image = random_horizontal_flip(image)
#      31     a= random_vertical_flip(augmented_image )
#      34     augmented_images.append(augmented_image)
#
# Cell In[6], line 16, in random_horizontal_flip(image)
#      14 def random_horizontal_flip(image):
#      15     if random.random() < 0.5:
# ---> 16         image = cv2.flip(image, 1)
#      17     return image
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'flip'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
# Iterate over the first 10 images in X and display them
for i, image in enumerate(augmented_images[10:20]):
    cv2.imshow(f'Image {i}', image)
    cv2.waitKey(0)  # Wait fo a key press
    cv2.destroyAllWindows()  # Close the image window when a key is pressed

# %%
X = np.append(X, augmented_images, axis=0)

# %%
import numpy as np



# Combine x_train and y_train into pairs
combined = list(zip(X, y))

# Shuffle the pairs
np.random.shuffle(combined)

# Unzip the shuffled pairs back into separate lists
x_train, y_train = zip(*combined)

# Now x_train_shuffled and y_train_shuffled are shuffled while maintaining their correspondence

# %%
len(y_train)
# Out:
# 735

# %%
X_val=[]
y_val=[]
for classe in os.listdir(test_dir):
    
    for img in os.listdir(os.path.join(test_dir,classe)):
        image_path=os.path.join(test_dir,classe,img)
        img = tf.io.read_file(image_path)
        img = tf.io.decode_jpeg(img, channels = 3)
        img = tf.image.resize(img, size = (224,224))
        img = tf.cast(img, tf.float32) / 255.0
        X_val.append(img)
        
        
        y_val.append(classe)

# %%
# Optionally, you can convert the lists into numpy arrays
X_train = np.array(x_train)
X_val = np.array(X_val)
y_train = np.array(y_train)
y_val = np.array(y_val)
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform string labels to integer labels
y_train_encoded = label_encoder.fit_transform(y_train)

# Convert integer labels to one-hot encoded format
y_train_encoded = to_categorical(y_train_encoded, num_classes=6)  # Assuming 6 classes


# Fit and transform string labels to integer labels
y_val_encoded = label_encoder.transform(y_val)

# Convert integer labels to one-hot encoded format
y_val= to_categorical(y_val_encoded, num_classes=6)  # A

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define data augmentation parameters
train_datagen = ImageDataGenerator(
    rescale=1./255,
    
    
  
    
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Define batch size
batch_size = 32

# Define input shape of the images (224x224 pixels with 3 color channels)
input_shape = (224, 224, 3)

# Create train and test generators with data augmentation
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],  # Only specify height and width for target size
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],  # Only specify height and width for target size
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 735 images belonging to 6 classes.
# Found 175 images belonging to 6 classes.

# %%
# Calculate the length of the training data generator after augmentation
num_batches_train = len(train_generator)

# Calculate the total number of samples in the training data generator
num_samples_train = num_batches_train * batch_size

print("Total number of samples in the training data generator after augmentation:", num_samples_train)
# Out:
# Total number of samples in the training data generator after augmentation: 736

# %% [markdown]
# <a id="4"></a>
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">4. Model Training with different architectures 🔍</div>

# %% [markdown]
# # Custom Model CNN

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import numpy as np

# Define your Keras model as a function
def create_model(optimizer='adam', dropout_rate=0.2, units=64):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (4, 4), activation='relu', input_shape=(244, 244, 3)))
    model.add(layers.Conv2D(120, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (2, 2), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(layers.BatchNormalization())
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(units, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(6, activation='softmax'))
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Split data into training and validation sets


# Define hyperparameters and their search space
param_grid = {
    'optimizer': ['adam', 'rmsprop'],
    'dropout_rate': [0.1, 0.2, 0.3],
    'units': [64, 128, 256]
}

# Create Keras classifier
model = KerasClassifier(build_fn=create_model, epochs=10, batch_size=32, verbose=1)

# Perform random search with validation data
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=10, cv=3, verbose=1)
random_search_result = random_search.fit(X_train, y_train_encoded, validation_data=(X_val, y_val))

# Print results
print("Best: %f using %s" % (random_search_result.best_score_, random_search_result.best_params_))
# Out:
# C:\Users\youss\AppData\Local\Temp\ipykernel_2984\3502110733.py:36: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=10, batch_size=32, verbose=0)
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 50
#      48 # Perform random search with validation data and custom callback
#      49 random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=3, cv=3, verbose=1)
# ---> 50 random_search_result = random_search.fit(X_train, y_train, validation_data=(X_val, y_val), callbacks=[ValidationMetricsCallback((X_val, y_val))])
#      52 # Print results
# ...

# %%
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 20
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train the model with early stopping
history = model.fit(X_train,y_train_encoded, epochs=num_epochs, validation_data=(X_val,y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 46/46 [==============================] - ETA: 0s - loss: 2.1056 - accuracy: 0.4435
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 9
#       5 early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#       8 # Train the model with early stopping
# ----> 9 history = simple_model.fit(X_train,y_train_encoded, epochs=num_epochs, validation_data=(X_val,y_val), callbacks=[early_stopping])
#
# File ~\anaconda3\envs\keypointsapproach\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
# ...

# %% [markdown]
# # 5 Submission

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (120, 120, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)

# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(GlobalAveragePooling2D())

# Add a BatchNormalization layer for regularization
model.add(BatchNormalization())

# Add a Dense layer with L2 regularization for classification
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Add a Dropout layer for regularization
model.add(Dropout(0.5))

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()

# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 3, 3, 1024)       3228864
#  nal)
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dense_29 (Dense)            (None, 256)               262400
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_30 (Dense)            (None, 6)                 1542
#
# ...
# Total params: 3,496,902
# Trainable params: 3,472,966
# Non-trainable params: 23,936
# _________________________________________________________________
# Epoch 1/30
# ...

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout,Flatten
from tensorflow.keras.optimizers import Adam

# Define input shape of the images (224x224 pixels with 3 color channels)
input_shape = (120, 120, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)
#base_model.layers[-1]=True
# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())

# Add a Dropout layer for regularizatio

# Add a Dense layer for classification
model.add(Dense(256, activation='relu'))

# Add a Dropout layer for regularization
model.add(Dropout(0.5))

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()

# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 15
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 3, 3, 1024)       3228864
#  nal)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 256)               2359552
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 6)                 1542
#
# ...
# Total params: 5,589,958
# Trainable params: 5,568,070
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/15
# 23/23 [==============================] - 34s 1s/step - loss: 2.2633 - accuracy: 0.4435 - val_loss: 0.6185 - val_accuracy: 0.7943
# Epoch 2/15
# ...

# %% [markdown]
# # 6 submission

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (224, 224, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.layers[-1]=True
# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())
model.add(BatchNormalization())

# Add a BatchNormalization layer for regularization

# Add a Dense layer with L2 regularization for classification
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

model.add(BatchNormalization())



# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()

# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)




# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  flatten_8 (Flatten)         (None, 50176)             0
#
#  batch_normalization_11 (Bat  (None, 50176)            200704
#  chNormalization)
#
#  dense_21 (Dense)            (None, 64)                3211328
#
#  batch_normalization_12 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_22 (Dense)            (None, 6)                 390
#
# ...
# Total params: 6,641,542
# Trainable params: 6,519,174
# Non-trainable params: 122,368
# _________________________________________________________________
# Epoch 1/30
# 25/25 [==============================] - 47s 2s/step - loss: 2.0526 - accuracy: 0.7265 - val_loss: 1.6712 - val_accuracy: 0.8514
# Epoch 2/30
# ...

# %% [markdown]
# # 8 submission

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (128, 128, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.layers[-1]=True
# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())
model.add(BatchNormalization())

# Add a BatchNormalization layer for regularization

# Add a Dense layer with L2 regularization for classification
model.add(Dense(12, activation='relu', kernel_regularizer=regularizers.l2(0.01)))




# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()

# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)




# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_128 (Functio  (None, 4, 4, 1024)       3228864
#  nal)
#
#  flatten_20 (Flatten)        (None, 16384)             0
#
#  batch_normalization_33 (Bat  (None, 16384)            65536
#  chNormalization)
#
#  dense_37 (Dense)            (None, 12)                196620
#
#  dense_38 (Dense)            (None, 6)                 78
#
# ...
# Total params: 3,491,098
# Trainable params: 3,436,442
# Non-trainable params: 54,656
# _________________________________________________________________
# Epoch 1/30
# 21/21 [==============================] - 38s 2s/step - loss: 1.6780 - accuracy: 0.4939 - val_loss: 1.1313 - val_accuracy: 0.7143
# Epoch 2/30
# 21/21 [==============================] - 31s 1s/step - loss: 0.6040 - accuracy: 0.9075 - val_loss: 0.7288 - val_accuracy: 0.8457
# Epoch 3/30
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import MobileNet

# Define input shape of the images (100x100 pixels with 3 color channels)
input_shape = (100, 100, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
base_model.layers[-1] = True

# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)
model.add(Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())

# Add dense layers with L2 regularization
model.add(Dense(64, activation='relu'))

# Add output layer with softmax activation for multi-class classification
model.add(Dense(num_classes, activation='softmax'))

# Print the model summary
model.summary()
# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)


# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
num_epochs = 100
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 3, 3, 1024)       3228864
#  nal)
#
#  conv2d_32 (Conv2D)          (None, 3, 3, 64)          589888
#
#  flatten_14 (Flatten)        (None, 576)               0
#
#  dense_25 (Dense)            (None, 64)                36928
#
#  dense_26 (Dense)            (None, 6)                 390
#
# ...
# Total params: 3,856,070
# Trainable params: 3,834,182
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 34s 2s/step - loss: 2.7784 - accuracy: 0.4435 - val_loss: 2.1760 - val_accuracy: 0.6400
# Epoch 2/100
# ...

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (224, 224, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.layers[-1]=True
# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(GlobalAveragePooling2D())
model.add(BatchNormalization())

# Add a Dense layer with dropout regularization
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Add dropout with a dropout rate of 0.5 (adjust as needed)

# Add batch normalization after dropout
model.add(BatchNormalization())

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()


# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)




# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  batch_normalization_6 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_6 (Dense)             (None, 64)                65600
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_7 (Dense)             (None, 6)                 390
#
# ...
# Total params: 3,299,206
# Trainable params: 3,275,142
# Non-trainable params: 24,064
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 45s 2s/step - loss: 1.6547 - accuracy: 0.3973 - val_loss: 2.0459 - val_accuracy: 0.3943
# Epoch 2/30
# ...

# %% [markdown]
# # submission 15

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing import image
import numpy as np


from tensorflow.keras.applications import  Xception
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (300, 300, 3)

# Load the pre-trained MobileNet model without the top layers
base_model =   Xception(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.layers[-1]=True
# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())

# Add a Dense layer with dropout regularization
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Add dropout with a dropout rate of 0.5 (adjust as needed)

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()


# Define optimizer with learning rate decay
batches_per_epoch = len(train_generator)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)




# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)


# Train the model with early stopping
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator, callbacks=[early_stopping])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  flatten_3 (Flatten)         (None, 100352)            0
#
#  dense_10 (Dense)            (None, 64)                6422592
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 6)                 390
#
# ...
# Total params: 27,284,462
# Trainable params: 27,229,934
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/30
# 23/23 [==============================] - 112s 5s/step - loss: 1.3443 - accuracy: 0.5088 - val_loss: 0.5248 - val_accuracy: 0.8057
# Epoch 2/30
# 23/23 [==============================] - 106s 5s/step - loss: 0.3601 - accuracy: 0.8925 - val_loss: 0.3437 - val_accuracy: 0.9257
# Epoch 3/30
# ...

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing import image
import numpy as np


from tensorflow.keras.applications import  Xception
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (224, 224, 3)

# Load the pre-trained MobileNet model without the top layers
base_model =   Xception(weights='imagenet', include_top=False, input_shape=input_shape)

# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())

# Add a Dense layer with dropout regularization
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Add dropout with a dropout rate of 0.5 (adjust as needed)

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()

batch_size=30
# Define optimizer with learning rate decay
batches_per_epoch = len(X_train)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)




# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)


# Train the model with early stopping
history = model.fit(X_train,y_train_encoded, epochs=num_epochs,batch_size=30, validation_data=(X_val,y_val), callbacks=[early_stopping])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  flatten_5 (Flatten)         (None, 100352)            0
#
#  dense_10 (Dense)            (None, 64)                6422592
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 6)                 390
#
# ...
# Total params: 27,284,462
# Trainable params: 27,229,934
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/30
# 49/49 [==============================] - 326s 6s/step - loss: 1.5374 - accuracy: 0.4007 - val_loss: 0.6389 - val_accuracy: 0.7714
# Epoch 2/30
# 49/49 [==============================] - 261s 5s/step - loss: 0.7364 - accuracy: 0.7272 - val_loss: 0.3732 - val_accuracy: 0.8800
# Epoch 3/30
# ...

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (224 ,224, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)

# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())

# Add a Dense layer with L2 regularization for classification
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Add a Dropout layer for regularization
model.add(Dropout(0.5))

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()
batch_size=30
# Define optimizer with learning rate decay
batches_per_epoch = len(X_train)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=6, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train,y_train_encoded, epochs=num_epochs,batch_size=30, validation_data=(X_val,y_val), callbacks=[early_stopping])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  flatten_8 (Flatten)         (None, 50176)             0
#
#  dense_20 (Dense)            (None, 256)               12845312
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_21 (Dense)            (None, 6)                 1542
#
# ...
# Total params: 16,075,718
# Trainable params: 16,053,830
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/30
# 49/49 [==============================] - 95s 2s/step - loss: 6.0839 - accuracy: 0.7150 - val_loss: 5.0197 - val_accuracy: 0.8914
# Epoch 2/30
# 49/49 [==============================] - 81s 2s/step - loss: 4.6379 - accuracy: 0.9728 - val_loss: 4.5533 - val_accuracy: 0.9600
# Epoch 3/30
# ...

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define input shape of the images (120x120 pixels with 3 color channels)
input_shape = (224 ,224, 3)

# Load the pre-trained MobileNet model without the top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)

# Create a new Sequential model
model = Sequential()

# Add the pre-trained MobileNet model as a layer
model.add(base_model)

# Add a GlobalAveragePooling2D layer to reduce the spatial dimensions
model.add(Flatten())

# Add a Dense layer with L2 regularization for classification
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Add a Dropout layer for regularization
model.add(Dropout(0.5))

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(6, activation='softmax'))  # Assuming 6 classes for your dataset

# Print the model summary
model.summary()
batch_size=30
# Define optimizer with learning rate decay
batches_per_epoch = len(X_train)*batch_size
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train,y_train_encoded, epochs=num_epochs,batch_size=30, validation_data=(X_val,y_val), callbacks=[early_stopping])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  flatten_4 (Flatten)         (None, 50176)             0
#
#  dense_12 (Dense)            (None, 256)               12845312
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 6)                 1542
#
# ...
# Total params: 16,075,718
# Trainable params: 16,053,830
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/30
# 49/49 [==============================] - 88s 2s/step - loss: 5.9482 - accuracy: 0.7415 - val_loss: 5.0683 - val_accuracy: 0.8971
# Epoch 2/30
# 49/49 [==============================] - 85s 2s/step - loss: 4.6346 - accuracy: 0.9755 - val_loss: 4.5871 - val_accuracy: 0.9657
# Epoch 3/30
# ...

# %% [markdown]
# <a id="5"></a>
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">5. Model Training with vit 🔍</div>

# %%
import tensorflow as tf
from tensorflow.keras import layers
from vit_keras import vit

# Définir le nombre de classes dans votre jeu de données
num_classes = 6  # Remplacez ... par le nombre de classes

# Téléchargez les poids pré-entraînés ViT à partir de TensorFlow Hub
pretrained_model = vit.vit_b16(
    image_size=(224, 224),
    pretrained=True,
    include_top=False,
    pretrained_top=False,
)

# Ajouter des couches supplémentaires au modèle ViT pré-entraîné 
inputs = tf.keras.Input(shape=(224, 224, 3))
x = pretrained_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

modell = tf.keras.Model(inputs=inputs, outputs=outputs)



batches_per_epoch = len(X_train)*30
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
modell.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 30
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='accuracy', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = modell.fit(X_train,y_train_encoded, epochs=num_epochs,batch_size=30, validation_data=(X_val,y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 25/25 [==============================] - 368s 14s/step - loss: 0.7262 - accuracy: 0.7483 - val_loss: 0.1285 - val_accuracy: 0.9714
# Epoch 2/30
# 25/25 [==============================] - 355s 14s/step - loss: 0.0472 - accuracy: 0.9905 - val_loss: 0.1176 - val_accuracy: 0.9771
# Epoch 3/30
# 25/25 [==============================] - 329s 13s/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0861 - val_accuracy: 0.9829
# Epoch 4/30
# 25/25 [==============================] - 331s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0928 - val_accuracy: 0.9771
# Epoch 5/30
# 25/25 [==============================] - 338s 13s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9829
# Epoch 6/30
# 25/25 [==============================] - 307s 12s/step - loss: 9.6402e-04 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9829
# Epoch 7/30
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers
from vit_keras import vit

# Définir le nombre de classes dans votre jeu de données
num_classes = 6  # Remplacez ... par le nombre de classes

# Téléchargez les poids pré-entraînés ViT à partir de TensorFlow Hub
pretrained_model = vit.vit_b16(
    image_size=(224, 224),
    pretrained=True,
    include_top=False,
    pretrained_top=False,
)


inputs = tf.keras.Input(shape=(224, 224, 3))
x = pretrained_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(12, activation='relu')(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

modell = tf.keras.Model(inputs=inputs, outputs=outputs)



batches_per_epoch = len(X_train)*30
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
modell.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 8
# Define the early stopping callback
#early_stopping = EarlyStopping(monitor='accuracy', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = modell.fit(X_train,y_train_encoded, epochs=num_epochs,batch_size=30, validation_data=(X_val,y_val))
# Out:
# C:\Users\youss\anaconda3\envs\keypointsapproach\lib\site-packages\vit_keras\utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 14, 14
#   warnings.warn(
# Epoch 1/8
# 25/25 [==============================] - 614s 23s/step - loss: 1.0326 - accuracy: 0.6068 - val_loss: 0.3389 - val_accuracy: 0.9371
# Epoch 2/8
# 25/25 [==============================] - 372s 15s/step - loss: 0.1505 - accuracy: 0.9728 - val_loss: 0.0962 - val_accuracy: 0.9886
# Epoch 3/8
# 25/25 [==============================] - 350s 14s/step - loss: 0.0312 - accuracy: 0.9973 - val_loss: 0.0660 - val_accuracy: 0.9943
# Epoch 4/8
# 25/25 [==============================] - 347s 14s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9943
# Epoch 5/8
# 25/25 [==============================] - 349s 14s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9943
# Epoch 6/8
# ...

# %% [markdown]
# **dAY 13/04**

# %%
import tensorflow as tf
from tensorflow.keras import layers
from vit_keras import vit

# Définir le nombre de classes dans votre jeu de données
num_classes = 6  # Remplacez ... par le nombre de classes

# Téléchargez les poids pré-entraînés ViT à partir de TensorFlow Hub
pretrained_model = vit.vit_b16(
    image_size=(224, 224),
    pretrained=True,
    include_top=False,
    pretrained_top=False,
)

# Créez votre modèle en ajoutant des couches supplémentaires au modèle ViT pré-entraîné pour votre tâche spécifique
inputs = tf.keras.Input(shape=(224, 224, 3))
x = pretrained_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(12, activation='relu')(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

modell = tf.keras.Model(inputs=inputs, outputs=outputs)



batches_per_epoch = len(X_train)*30
lr_decay = (1./0.75 - 1) / batches_per_epoch
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001, decay=lr_decay)

# Compile the model with Adam optimizer
modell.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
num_epochs = 20
# Define the early stopping callback
#early_stopping = EarlyStopping(monitor='accuracy', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = modell.fit(X_train,y_train_encoded, epochs=num_epochs,batch_size=30, validation_data=(X_val,y_val))
# Out:
# Epoch 1/20
# 25/25 [==============================] - 421s 16s/step - loss: 0.9302 - accuracy: 0.6367 - val_loss: 0.3360 - val_accuracy: 0.9029
# Epoch 2/20
# 25/25 [==============================] - 372s 15s/step - loss: 0.1515 - accuracy: 0.9660 - val_loss: 0.1278 - val_accuracy: 0.9657
# Epoch 3/20
# 25/25 [==============================] - 369s 15s/step - loss: 0.0323 - accuracy: 0.9959 - val_loss: 0.0678 - val_accuracy: 0.9829
# Epoch 4/20
# 25/25 [==============================] - 369s 15s/step - loss: 0.0111 - accuracy: 0.9986 - val_loss: 0.0639 - val_accuracy: 0.9771
# Epoch 5/20
# 25/25 [==============================] - 377s 15s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9771
# Epoch 6/20
# 25/25 [==============================] - 372s 15s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9771
# Epoch 7/20
# ...

# %%
def img_preprocessing(image, label):
    img = tf.io.read_file(image)
    img = tf.io.decode_jpeg(img, channels = 3)
    img = tf.image.resize(img, size = (IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0
    
    return img, label


# Basic data augmentation 
def augmentation(image, label):
    img = tf.image.random_flip_left_right(image)
    img = tf.image.random_flip_up_down(img)
    
    return image, label

# %% [markdown]
# # Submission

# %%
import os
# Save the trained model
#model.save("mobilenet_sumbission14.h5")

testt=os.path.join("MLAct-MLO2024-Dataset","test")

# %%
from PIL import Image
import cv2
from tensorflow.keras.models import load_model
import numpy as np
# Load the saved model
#model = load_model("mobilenet_freezeall.h5")
#classes=["barrel_jellyfish","compass_jellyfish","lions_mane_jellyfish","mauve_stinger_jellyfish","moon_jellyfish","plastic_pollution"]
SIZE=224
predictions=[]
images=[]
for img in os.listdir(testt)[1:]:
    images.append(img[:-4])
    print(img)
    path = os.path.join(testt, img)
    img = tf.io.read_file(path)
    img = tf.io.decode_jpeg(img, channels = 3)
    img = tf.image.resize(img, size = (224,224))
    img = tf.cast(img, tf.float32) / 255.0
        
    
      # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add a dimension for batch
    pred = modell.predict(img)
    predicted_class_index = np.argmax(pred, axis=1)[0]
    print(predicted_class_index)
    
    # Decode predicted class index to original class label
    predicted_class = label_encoder.inverse_transform([predicted_class_index])[0]
    # Append predictions to the corresponding list
    predictions.append(predicted_class)
# Out:
# img003751.jpg
# 1/1 [==============================] - 5s 5s/step
# 4
# img004022.jpg
# 1/1 [==============================] - 0s 155ms/step
# 4
# img005714.jpg
# 1/1 [==============================] - 0s 155ms/step
# 3
# img007896.jpg
# 1/1 [==============================] - 0s 153ms/step
# 3
# img008637.jpg
# 1/1 [==============================] - 0s 160ms/step
# 1
# img009132.jpg
# 1/1 [==============================] - 0s 169ms/step
# 4
# img011827.jpg
# 1/1 [==============================] - 0s 160ms/step
# 1
# img014358.jpg
# 1/1 [==============================] - 0s 158ms/step
# 5
# img014928.jpg
# 1/1 [==============================] - 0s 145ms/step
# 3
# img017431.jpg
# 1/1 [==============================] - 0s 152ms/step
# 5
# img019127.jpg
# 1/1 [==============================] - 0s 156ms/step
# 5
# img023562.jpg
# 1/1 [==============================] - 0s 151ms/step
# 5
# img028254.jpg
# 1/1 [==============================] - 0s 143ms/step
# 4
# img030839.jpg
# ...

# %%
label_encoder.inverse_transform([6])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 label_encoder.inverse_transform([6])
#
# File ~\anaconda3\envs\keypointsapproach\lib\site-packages\sklearn\preprocessing\_label.py:160, in LabelEncoder.inverse_transform(self, y)
#     158 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     159 if len(diff):
# --> 160     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     161 y = np.asarray(y)
#     162 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [6]

# %%
predicted_class
# Out:
# 'plastic_pollution'

# %%
submission=pd.DataFrame({'ImageID':images ,'PredictedClass':predictions})

# %%
# Save the DataFrame to a CSV file
submission.to_csv('submission_23.csv', index=False)

# %%
sub=pd.read_csv('submission.csv')

# %%
predictions
# Out:
# ['moon_jellyfish',
#  'moon_jellyfish',
#  'mauve_stinger_jellyfish',
#  'mauve_stinger_jellyfish',
#  'compass_jellyfish',
#  'moon_jellyfish',
#  'lions_mane_jellyfish',
#  'plastic_pollution',
#  'mauve_stinger_jellyfish',
#  'plastic_pollution',
#  'plastic_pollution',
#  'plastic_pollution',
#  'moon_jellyfish',
#  'plastic_pollution',
#  'mauve_stinger_jellyfish',
#  'mauve_stinger_jellyfish',
#  'barrel_jellyfish',
#  'lions_mane_jellyfish',
#  'plastic_pollution',
#  'barrel_jellyfish',
#  'lions_mane_jellyfish',
#  'barrel_jellyfish',
#  'mauve_stinger_jellyfish',
#  'compass_jellyfish',
#  'compass_jellyfish',
#  'barrel_jellyfish',
#  'moon_jellyfish',
#  'compass_jellyfish',
#  'lions_mane_jellyfish',
#  'mauve_stinger_jellyfish',
#  'mauve_stinger_jellyfish',
#  'moon_jellyfish',
#  'compass_jellyfish',
#  'moon_jellyfish',
#  'lions_mane_jellyfish',
#  'plastic_pollution',
#  'plastic_pollution',
#  'plastic_pollution',
#  'compass_jellyfish',
# ...

# %%
modell.save("vitb16.h5")

# %%
submission
# Out:
#        ImageID           PredictedClass
# 0    img003751           moon_jellyfish
# 1    img004022           moon_jellyfish
# 2    img005714  mauve_stinger_jellyfish
# 3    img007896  mauve_stinger_jellyfish
# 4    img008637        compass_jellyfish
# ..         ...                      ...
# 475  img992880        plastic_pollution
# 476  img994096         barrel_jellyfish
# 477  img995443        compass_jellyfish
# 478  img997987        compass_jellyfish
# 479  img999308        plastic_pollution
#
# [480 rows x 2 columns]

# %%
submission
# Out:
#        ImageID           PredictedClass
# 0    img003751           moon_jellyfish
# 1    img004022           moon_jellyfish
# 2    img005714  mauve_stinger_jellyfish
# 3    img007896  mauve_stinger_jellyfish
# 4    img008637        compass_jellyfish
# ..         ...                      ...
# 475  img992880        plastic_pollution
# 476  img994096         barrel_jellyfish
# 477  img995443        compass_jellyfish
# 478  img997987        compass_jellyfish
# 479  img999308        plastic_pollution
#
# [480 rows x 2 columns]

# %%
predictions
# Out:
# ['moon_jellyfish',
#  'mauve_stinger_jellyfish',
#  'mauve_stinger_jellyfish',
#  'compass_jellyfish',
#  'moon_jellyfish',
#  'compass_jellyfish',
#  'plastic_pollution',
#  'mauve_stinger_jellyfish',
#  'plastic_pollution',
#  'plastic_pollution',
#  'plastic_pollution',
#  'moon_jellyfish',
#  'plastic_pollution',
#  'mauve_stinger_jellyfish',
#  'mauve_stinger_jellyfish',
#  'barrel_jellyfish',
#  'lions_mane_jellyfish',
#  'plastic_pollution',
#  'barrel_jellyfish',
#  'lions_mane_jellyfish',
#  'barrel_jellyfish',
#  'mauve_stinger_jellyfish',
#  'compass_jellyfish',
#  'compass_jellyfish',
#  'barrel_jellyfish',
#  'barrel_jellyfish',
#  'mauve_stinger_jellyfish',
#  'compass_jellyfish',
#  'mauve_stinger_jellyfish',
#  'mauve_stinger_jellyfish',
#  'moon_jellyfish',
#  'compass_jellyfish',
#  'plastic_pollution',
#  'lions_mane_jellyfish',
#  'plastic_pollution',
#  'barrel_jellyfish',
#  'barrel_jellyfish',
#  'compass_jellyfish',
#  'plastic_pollution',
# ...

# %%
import cv2
import os

# Assuming 'testt' contains the path to the test directory
test_images = os.listdir(testt)[15:50]  # Select a subset of images
i = 15
for img in test_images:
    path = os.path.join(testt, img)
    image = cv2.imread(path)
    image = cv2.resize(image, (244, 244)) 
    text = f'Prediction: {predictions[i]}'  # Assuming 'predictions' contains the model predictions
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.5
    thickness = 1
    text_size = cv2.getTextSize(text, font, font_scale, thickness)[0]

    # Calculate text position
    text_x = (image.shape[1] - text_size[0]) // 2
    text_y = (image.shape[0] + text_size[1]) // 2

    # Display image with prediction
    cv2.putText(image, text, (text_x, text_y), font, font_scale, (255, 255, 0), thickness)
    
    cv2.imshow('Image with Prediction', image)
    cv2.waitKey(0)  # Wait for any key to be pressed
    cv2.destroyAllWindows()  # Close all OpenCV windows
    
    i += 1

# %%
#model = load_model("mobilenet_withhorizontalflip.h5")
classes=["barrel_jellyfish","compass_jellyfish","lions_mane_jellyfish","mauve_stinger_jellyfish","moon_jellyfish","plastic_pollution"]
SIZE=120
predictions=[]
images=[]
test_images = os.listdir(testt)
for img in os.listdir(testt):
   
    path = os.path.join(testt, img)
    image_data = cv2.imread(path)  # Read the image using OpenCV
    img = cv2.resize(image_data, (SIZE, SIZE))  # Resize the image
    
    img = img / 255.0  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add a dimension for batch
    pred = model.predict(img)
    cv2.imshow('Image with Prediction', image_data)
    print(classes[np.argmax(pred, axis=1)[0]])

# %%
os.listdir(testt)[470:]
# Out:
# ['img984465.jpg',
#  'img986137.jpg',
#  'img989684.jpg',
#  'img990537.jpg',
#  'img992515.jpg',
#  'img992880.jpg',
#  'img994096.jpg',
#  'img995443.jpg',
#  'img997987.jpg',
#  'img999308.jpg']
